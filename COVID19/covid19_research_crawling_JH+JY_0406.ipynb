# %% [markdown]
# # 2020-04-03
# ## 언론은 국민들에게 얼마나 많은 영향을 끼치는가?
# ### 코로나 관련 키워드로 쓰인 기사들을 위주로 분석
#
# Search_Trend.csv 데이터에서 코로나의 검색량과 확진자수의 변화를 보자 최초 확진자가 발생한 시점에 가장 많은 검색량이 발생했고, 확진자가 급증한 2월 18일부터 5일간 엄청난 증가세를 보였다. 확진자의 증가추세에 따라 사람들의 심리적 불안감이 나타났음을 의미한다.
#
# --->>
#
# 우리나라에 최초 코로나 바이러스 발생한 시점에 검색량이 가장 많았다는 것은 사람들의 "심리적 불안감"과 동시에 코로나 바이러스에 대한 궁금증이 앞섰기 때문이라고 생각했다. 때문에 이 시기에 언론은 코로나 바이러스 확진자는 누구인지, 어디에서 왔는지를 중심으로 기사를 썼을 것이라 생각한다. 이것 뿐만 아니라 코로나 바이러스의 발원지라 추측되고 있는 우한은 도대체 어느 곳인지, 바이러스 증상은 어떠한지, 중국의 상황은 얼마나 심각한지에 대한 내용 또한 다뤘을 것이며, 현재 다른나라들, 특히 중국과 인접해있는 국가들은 어떻게 대처하고 있고, 우리나라는 앞으로 어떻게 대처해야 할 것인지도 역시 이야기했을 것이다.
#
# 이후 코로나 관련키워드로는 WHO, 중국발 입국금지, 질병관리본부, 마스크 5부제 시행, 코로나 맵, 신천지, 청도 대남 병원, (짜파구리) 등 다양하게 생각해 볼 수 있다. 이 키워드들 역시 핫 키워드로 실시간 연관검색어에 올랐으며 각각에 대해서 언론들은 긍정적으로 혹은 부정적으로 많은 기사를 썼을 것이다. 따라서 단순히 '코로나'검색양으로 확진자 수와 연관을 짓는 것은 옳지 않다고 생각하며, '코로나 관련 키워드'로 생각을 해야 좀 더 의미있는 인사이트를 찾을 수 있을 것이라 생각했다.
#
# 1. 해당 기간 내에 작성된 네이버 기사 크롤링
# 2. 기사 분석
#   - 기사 제목의 감정 분석
#   - 기사를 읽은 네티즌들의 반응 분석
#   - 기사의 주요 키워드 분석
# 3. 언론이 네티즌들의 '코로나' 관심에 얼마나 많은 영향을 끼치는가?

# %% [markdown]
# # 코로나 관련 기사 웹 크롤링에 대한 JH 생각.
#
# ### 1. 크롤링을 하는 거면,
#
# **우리가 가지고 있는 어떤 그래프(확진자수, 테스트한 사람수, 사망자수)를 가지고 코로나의 Timeline을 짜보는 것은 어떨까?**
#
#
# ## 지금 주제 :
# ## (인터넷) 뉴스가 국민들에게 어떠한 영향을 주었는가?

# %% [markdown]
# ## 1. 기사 제목의 감정분석 ->
#
# 감정분석까지 한다는 이야기?
#
# 크롤링을 해서 감정분석 -> 코로나에 대한 기자의 관점.
#
# **해당 독자가 어떻게 느꼈는지에 대한 확실한 근거라고 볼 수 있을까?**
#
#
# ## 2. 기사를 읽은 네티즌들의 반응 분석 ->
#
# 네티즌들의 반응을 본다는 것이 어떤 것을 이용을 할 것인가?
#
# 댓글에 대한 감정분석? 이것을 감정분석을 한다고 하면,
#
# **과연 댓글을 단 사람이 인터넷 뉴스를 본 모든 사람의 입장을 대변한다고 생각을 할 수 있는가?**

# %% [markdown]
# ## 네이버의 실검순위를 한번 크롤링해서 가져오는 것은 어떨까?
#
# **이유 1**. 일단 기사제목이나, 댓글은 한 문장이지만, 실검의 순위 하나는 한 단어이므로 컴퓨터 성능에 대한 로딩이 덜 할 수 있다.
#
# **이유 2**. 내 생각에는 댓글을 다는 사람이 뉴스를 보거나 검색하는 사람들의 입장을 100 퍼센트 대변해주지 못한다고 본다.
#
#  실검 순위를 조사함으로써, 조금 더 넓은 범위의 사람의 반응을 볼 수 있을 거라고 생각을 했고, 단지 코로나 뿐만이 아닌, 코로나로 인하여 생겨나는 현상
#
#  (우리가 생각하기에 큰 연관이 없을 거라고 생각했던,
#
# 예를 들어, 주가가 크게 떨어지면서, 어느 시점 이후부터는 사람들이 정작 코로나, 확진자보다는 주가, 경제에 더 신경을 쓰는지에 대해서도 알 수 있을 것이라고 본다.)
#
# ### 이렇게 된다면 주제가 조금 바뀔 것.

# %% [markdown]
# 실검 순위를 크롤링을 해서 데이터를 뽑아 시각화를 하게 된다면,
# 일단, 실검순위를 뽑는 것이 법적으로 문제가 없는지를 확인을 해야겠고,
#
# 만약 이게 된다면, 막대그래프나 아니면, 막대그래프의 수치가 변화하는 애니메이션 그래프를 한번 적용해보고 싶다.
#
# 예시 링크 : https://www.youtube.com/watch?v=UMXi9rfRKh0

# %% [markdown]
# ### *논점 하나>
#
# 감정 분석이라는 것을 어떻게 할 것인가?
#
# 우리가 저번에 배웠던 머신러닝을 통해서? 만약 그게 된다고 하면, 신뢰성을 어떻게 보장?
#
# 샘플 데이터가 이미 존재하고 있어야 하는데, 샘플 데이터 어떻게 구할 것인가?
#
# 샘플 데이터의 기준은 어떻게 될 것인가?
#
#
# ### *논점 둘>
#
# 기사의 제목을 신뢰할 수 있는가?
#
# 기사의 제목은 현혹시키는 문구가 많은데, 실상으로 내용을 들여다 보면 아닌경우도 종종 있다.
#
# **기사의 주요 키워드 분석하는 것은 좋다**고 본다.
# 시간이 지남에 따라, **기사의 제목들이  코로나를 어떤 관점으로 보는지**에 대한 변화를 보는 것도 좋을 듯.

# %% [markdown]
# ## 내가 생각하고 있는 것
#
#
# ### 1. 네이버 실검 순위
# ### 2. 시간에 따른 기사의 코로나 관련 관점 변화
# ### 3. 코로나 타임라인.

# %% [markdown]
# # 2020-04-04
#
# 1. 네이버 기사 제목과 주요뉴스의 내용을 중심으로 키워드 추출 -> 코로나에 대한 관심도의 정도 (의식의 정도)
# 2. 그렇게 추출한 키워드를 가지고 타임라인을 만들어 냄.
# 3. 코로나 관련 키워드와 아닌 키워드를 군집화.

# %% [markdown]
# # 네이버 뉴스 크롤링

# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# 2020-04-03 랭킹뉴스 url 살펴보기
#
# 각 랭킹뉴스에는 총 30개의 기사가 있다.
#  - 정치 : https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=100&date=20200403
#  - 경제 : https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20200403
#  - 사회 : https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=102&date=20200403
#  - 생활/문화 : https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=103&date=20200403
#  - 세계 : https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=104&date=20200403
#  - IT/과학 https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=105&date=20200403
#
#
# 기본 : https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&
#  - 정치 : sectionId=100
#  - 경제 : sectionId=101
#  - 사회 : sectionId=102
#  - 생활/문화 : sectionId=103
#  - 세계 : sectionId=104
#  - IT/과학 : sectionId=105
#
#
# 날짜 : 20200403(년월일)

# %% [markdown]
# ## 정치분야 주요뉴스 헤드라인과 조회수

# %%
url = "https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=100&date=20200403"
resp = requests.get(url)
soup = BeautifulSoup(resp.text, "html.parser")
ranking_text = soup.find_all(class_ = 'ranking_text')

# %%
ranking_text[0]
# Out:
# <div class="ranking_text">
# <div class="ranking_headline">
# <a class="nclicks(rnk.gov)" href="/main/ranking/read.nhn?rankingType=popular_day&amp;oid=008&amp;aid=0004389031&amp;date=20200403&amp;type=1&amp;rankingSectionId=100&amp;rankingSeq=1" title='베트남, 한국인 막더니…이제와서 "방역 협력" 요청'>베트남, 한국인 막더니…이제와서 "방역 협력" 요청</a>
# </div>
# <div class="ranking_lede">
#
#                             [머니투데이 김성휘 기자] [[the300]文대통령-푹 총리 전화통화] 베트남은 코로나19 확산 초기 한국발 입국자 제한을 앞서서 적용했 …
#                         </div>
# <div class="ranking_office">머니투데이</div>
# <div class="ranking_view">256,162</div>
# </div>

# %%
l = []
for item in ranking_text:
    d = {}
    d['LinkSrc'] = item.find('a')['href']
    d['Title'] = item.find('a')['title']
    d['Views'] = item.find(class_ = "ranking_view").get_text()
    l.append(d)

# %%
l
# Out:
# [{'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=008&aid=0004389031&date=20200403&type=1&rankingSectionId=100&rankingSeq=1',
#   'Title': '베트남, 한국인 막더니…이제와서 "방역 협력" 요청',
#   'Views': '256,162'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=009&aid=0004550119&date=20200403&type=1&rankingSectionId=100&rankingSeq=2',
#   'Title': '안철수의 호소 "혈세로 초호화판 선거치를 때인가…지원금 440억 반납하자"',
#   'Views': '210,652'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=437&aid=0000235122&date=20200403&type=2&rankingSectionId=100&rankingSeq=3',
#   'Title': "주한미군사령관의 무례한 '김칫국 마시다' 리트윗 논란",
#   'Views': '208,315'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=032&aid=0003001662&date=20200403&type=1&rankingSectionId=100&rankingSeq=4',
#   'Title': '안철수 “정당 선거지원금 440억원 반납하고 투표참가자들에게 마스크 지급하자”',
#   'Views': '189,312'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=015&aid=0004318422&date=20200403&type=1&rankingSectionId=100&rankingSeq=5',
#   'Title': '나경원 "제 딸 유세현장 참석…나쁜 프레임에 흔들리지 않겠다"',
#   'Views': '179,883'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=015&aid=0004318102&date=20200403&type=1&rankingSectionId=100&rankingSeq=6',
#   'Title': '나경원 딸 "중국인 안막아 코로나 터져"…나경원 "우리 딸 씩씩하죠?"',
#   'Views': '165,712'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=005&aid=0001307502&date=20200403&type=1&rankingSectionId=100&rankingSeq=7',
#   'Title': '“정부가 중국인 안 막아 코로나 터졌다” 나경원 딸이 출정식에서 한 말',
#   'Views': '161,664'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=032&aid=0003001638&date=20200403&type=1&rankingSectionId=100&rankingSeq=8',
#   'Title': '황교안, 이번엔 신체비하 “키 작은 사람 비례 투표용지 못 들어” [총선 D - 12]',
#   'Views': '157,030'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=008&aid=0004388554&date=20200403&type=1&rankingSectionId=100&rankingSeq=9',
#   'Title': "韓진단키트 거절 '치명적 실수'라던 덴마크, 文과 통화에서 한말은?",
#   'Views': '134,929'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=003&aid=0009793621&date=20200403&type=1&rankingSectionId=100&rankingSeq=10',
#   'Title': '나경원, 딸과 단상 올라 울먹…딸 "중국인 안 막아 코로나 터져"(종합)',
#   'Views': '127,406'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=022&aid=0003453208&date=20200403&type=1&rankingSectionId=100&rankingSeq=11',
#   'Title': '[속보] 文대통령 “2022년까지 예비군 훈련보상비 추가인상 계획…현 정부 출범 후 4배 인상”',
#   'Views': '121,937'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=005&aid=0001307650&date=20200403&type=1&rankingSectionId=100&rankingSeq=12',
#   'Title': '[포착] 시민 돕는 ‘분홍코트’ 배현진, 발목 감은 ‘이것’',
#   'Views': '121,675'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=449&aid=0000189456&date=20200403&type=1&rankingSectionId=100&rankingSeq=13',
#   'Title': '안철수 “모든 정당, 선거지원금 440억 원 반납하자”',
#   'Views': '121,653'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=023&aid=0003520667&date=20200403&type=1&rankingSectionId=100&rankingSeq=14',
#   'Title': '유시민, 검사장 실명 공개 "명예훼손? 그럼 날 고소하라"',
#   'Views': '121,571'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=056&aid=0010814029&date=20200403&type=1&rankingSectionId=100&rankingSeq=15',
#   'Title': '주한미군사령관이 이틀 연속 ‘김치 메시지’를 낸 이유는?',
#   'Views': '108,159'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=028&aid=0002492145&date=20200403&type=1&rankingSectionId=100&rankingSeq=16',
#   'Title': '[2020총선] ‘설화’ 황교안 “사사건건 꼬투리…적당히들 하라” 발끈',
#   'Views': '107,094'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=022&aid=0003453109&date=20200403&type=1&rankingSectionId=100&rankingSeq=17',
#   'Title': '‘왜 하필 잠실이냐?’ 한마음으로 외친 최재성·배현진',
#   'Views': '106,141'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=437&aid=0000235154&date=20200403&type=2&rankingSectionId=100&rankingSeq=18',
#   'Title': "긴급재난지원금 선정 기준…3월 납부한 '건강보험료'",
#   'Views': '104,884'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=025&aid=0002990122&date=20200403&type=1&rankingSectionId=100&rankingSeq=19',
#   'Title': "꼼수 논란 '쌍둥이 버스' 금지···선관위 결정에 민주당 반발",
#   'Views': '102,672'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=023&aid=0003520677&date=20200403&type=1&rankingSectionId=100&rankingSeq=20',
#   'Title': '비례정당 예상 득표율…범여 3개 정당 53%, 미래한국당 31%',
#   'Views': '102,549'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=025&aid=0002989969&date=20200403&type=1&rankingSectionId=100&rankingSeq=21',
#   'Title': "'영원한 재야' 장기표의 추격···'친노 안방' 김해을 심상찮다",
#   'Views': '98,418'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=366&aid=0000504024&date=20200403&type=1&rankingSectionId=100&rankingSeq=22',
#   'Title': "'포레스트 철수'의 역설...달리기 동영상 조회수 10만 넘었는데",
#   'Views': '94,346'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=011&aid=0003719385&date=20200403&type=1&rankingSectionId=100&rankingSeq=23',
#   'Title': "[꼬인 한미 방위비협상] 너무 가벼웠던 '청와대 입'... 트럼프 역공 불렀다",
#   'Views': '93,460'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=437&aid=0000235124&date=20200403&type=2&rankingSectionId=100&rankingSeq=24',
#   'Title': "잠실운동장 '워크 스루' 놓고…송파을 여야 후보 모두 '반발'",
#   'Views': '92,874'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=022&aid=0003453317&date=20200403&type=1&rankingSectionId=100&rankingSeq=25',
#   'Title': '현역 군인이 ‘박사방’ 공범..휴대폰 사용 군서 사병들도 봤나',
#   'Views': '86,858'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=057&aid=0001439907&date=20200403&type=1&rankingSectionId=100&rankingSeq=26',
#   'Title': '나경원 딸 "중국인 안 막아 코로나 터졌다"…나경원 하는 말이',
#   'Views': '86,022'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=025&aid=0002990055&date=20200403&type=1&rankingSectionId=100&rankingSeq=27',
#   'Title': '비례정당 예상득표율, 미래한국31%·시민26%·정의15%·열린민주12% [갤럽]',
#   'Views': '84,898'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=052&aid=0001423473&date=20200403&type=1&rankingSectionId=100&rankingSeq=28',
#   'Title': '황교안 "키 작은 사람 투표 용지 들지도 못 해...선거가 코미디"',
#   'Views': '82,841'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=448&aid=0000295001&date=20200403&type=2&rankingSectionId=100&rankingSeq=29',
#   'Title': '긴급재난지원금 기준 발표…건보료·종부세 적용 유력',
#   'Views': '82,724'},
#  {'LinkSrc': '/main/ranking/read.nhn?rankingType=popular_day&oid=005&aid=0001307673&date=20200403&type=1&rankingSectionId=100&rankingSeq=30',
#   'Title': '“속 터져, 거지같아, 깡통, 폭망” 입 거칠어지는 통합당',
#   'Views': '81,506'}]

# %%
df = pd.DataFrame(l)
df
# Out:
#                                               LinkSrc  \
# 0   /main/ranking/read.nhn?rankingType=popular_day...
# 1   /main/ranking/read.nhn?rankingType=popular_day...
# 2   /main/ranking/read.nhn?rankingType=popular_day...
# 3   /main/ranking/read.nhn?rankingType=popular_day...
# 4   /main/ranking/read.nhn?rankingType=popular_day...
# 5   /main/ranking/read.nhn?rankingType=popular_day...
# 6   /main/ranking/read.nhn?rankingType=popular_day...
# 7   /main/ranking/read.nhn?rankingType=popular_day...
# 8   /main/ranking/read.nhn?rankingType=popular_day...
# 9   /main/ranking/read.nhn?rankingType=popular_day...
# 10  /main/ranking/read.nhn?rankingType=popular_day...
# 11  /main/ranking/read.nhn?rankingType=popular_day...
# 12  /main/ranking/read.nhn?rankingType=popular_day...
# 13  /main/ranking/read.nhn?rankingType=popular_day...
# 14  /main/ranking/read.nhn?rankingType=popular_day...
# 15  /main/ranking/read.nhn?rankingType=popular_day...
# 16  /main/ranking/read.nhn?rankingType=popular_day...
# 17  /main/ranking/read.nhn?rankingType=popular_day...
# 18  /main/ranking/read.nhn?rankingType=popular_day...
# 19  /main/ranking/read.nhn?rankingType=popular_day...
# 20  /main/ranking/read.nhn?rankingType=popular_day...
# 21  /main/ranking/read.nhn?rankingType=popular_day...
# 22  /main/ranking/read.nhn?rankingType=popular_day...
# 23  /main/ranking/read.nhn?rankingType=popular_day...
# 24  /main/ranking/read.nhn?rankingType=popular_day...
# 25  /main/ranking/read.nhn?rankingType=popular_day...
# 26  /main/ranking/read.nhn?rankingType=popular_day...
# 27  /main/ranking/read.nhn?rankingType=popular_day...
# 28  /main/ranking/read.nhn?rankingType=popular_day...
# 29  /main/ranking/read.nhn?rankingType=popular_day...
#
#                                                 Title    Views
# 0                        베트남, 한국인 막더니…이제와서 "방역 협력" 요청  256,162
# 1           안철수의 호소 "혈세로 초호화판 선거치를 때인가…지원금 440억 반납하자"  210,652
# 2                       주한미군사령관의 무례한 '김칫국 마시다' 리트윗 논란  208,315
# 3         안철수 “정당 선거지원금 440억원 반납하고 투표참가자들에게 마스크 지급하자”  189,312
# 4                  나경원 "제 딸 유세현장 참석…나쁜 프레임에 흔들리지 않겠다"  179,883
# 5             나경원 딸 "중국인 안막아 코로나 터져"…나경원 "우리 딸 씩씩하죠?"  165,712
# 6             “정부가 중국인 안 막아 코로나 터졌다” 나경원 딸이 출정식에서 한 말  161,664
# 7    황교안, 이번엔 신체비하 “키 작은 사람 비례 투표용지 못 들어” [총선 D - 12]  157,030
# 8               韓진단키트 거절 '치명적 실수'라던 덴마크, 文과 통화에서 한말은?  134,929
# 9            나경원, 딸과 단상 올라 울먹…딸 "중국인 안 막아 코로나 터져"(종합)  127,406
# 10  [속보] 文대통령 “2022년까지 예비군 훈련보상비 추가인상 계획…현 정부 출범 후...  121,937
# 11                  [포착] 시민 돕는 ‘분홍코트’ 배현진, 발목 감은 ‘이것’  121,675
# 12                     안철수 “모든 정당, 선거지원금 440억 원 반납하자”  121,653
# 13                   유시민, 검사장 실명 공개 "명예훼손? 그럼 날 고소하라"  121,571
# 14                    주한미군사령관이 이틀 연속 ‘김치 메시지’를 낸 이유는?  108,159
# 15            [2020총선] ‘설화’ 황교안 “사사건건 꼬투리…적당히들 하라” 발끈  107,094
# 16                      ‘왜 하필 잠실이냐?’ 한마음으로 외친 최재성·배현진  106,141
# 17                       긴급재난지원금 선정 기준…3월 납부한 '건강보험료'  104,884
# 18                 꼼수 논란 '쌍둥이 버스' 금지···선관위 결정에 민주당 반발  102,672
# 19                비례정당 예상 득표율…범여 3개 정당 53%, 미래한국당 31%  102,549
# 20                '영원한 재야' 장기표의 추격···'친노 안방' 김해을 심상찮다   98,418
# 21               '포레스트 철수'의 역설...달리기 동영상 조회수 10만 넘었는데   94,346
# 22        [꼬인 한미 방위비협상] 너무 가벼웠던 '청와대 입'... 트럼프 역공 불렀다   93,460
# 23                 잠실운동장 '워크 스루' 놓고…송파을 여야 후보 모두 '반발'   92,874
# 24                 현역 군인이 ‘박사방’ 공범..휴대폰 사용 군서 사병들도 봤나   86,858
# 25                 나경원 딸 "중국인 안 막아 코로나 터졌다"…나경원 하는 말이   86,022
# 26       비례정당 예상득표율, 미래한국31%·시민26%·정의15%·열린민주12% [갤럽]   84,898
# 27              황교안 "키 작은 사람 투표 용지 들지도 못 해...선거가 코미디"   82,841
# 28                        긴급재난지원금 기준 발표…건보료·종부세 적용 유력   82,724
# 29                   “속 터져, 거지같아, 깡통, 폭망” 입 거칠어지는 통합당   81,506

# %% [markdown]
# ## 정치 주요뉴스 기사내용 크롤링
# 앞에서 주요뉴스의 주소를 가져와 url을 만든 후 본문태그만 가져온다.

# %%
resp = requests.get("http://news.naver.com" + df.loc[0, 'LinkSrc'])
soup = BeautifulSoup(resp.text, "html.parser")
content = soup.find(id="articleBodyContents")
content
# Out:
# <div class="_article_body_contents" id="articleBodyContents">
# <!-- 본문 내용 -->
# <!-- TV플레이어 -->
# <!-- // TV플레이어 -->
# <script type="text/javascript">
# // flash 오류를 우회하기 위한 함수 추가
# function _flash_removeCallback() {}
# </script>
#
# 	[머니투데이 김성휘  기자] [[the300]文대통령-푹 총리 전화통화]<br/><br/>베트남은 코로나19 확산 초기 한국발 입국자 제한을 앞서서 적용했던 나라중 하나다. <br/><br/>자국민 안전을 위한 조치였지만 한국은 베트남 최대 투자국이자 제2위 교역국이고 베트남 역시 한국의 제4위 교역국이다. 베트남이 그런 한국에 과도한 조치를 한 것 아니냔 국내반응이 많았다.<br/><br/>베트남은 3일 응우옌 쑤언 푹 총리와 문재인 대통령의 전화통화에서 양국 관계를 중시한다며 방역 등에 협조를 요청했다. 우리 항공기의 착륙을 불허, 돌연 회항을 초래할 정도였던 것과 달라진 태도라는 평가가 나온다.  <br/><br/><span class="end_photo_org"><img alt="" src="https://imgnews.pstatic.net/image/008/2020/04/03/0004389031_001_20200403195002543.jpg?type=w647"><em class="img_desc">[서울=뉴시스]박영태 기자 = 문재인 대통령이 2일 오전 청와대 여민관에서 이반 두케 콜롬비아 대통령과 전화 통화하고 있다.(사진=청와대 제공) 2020.04.02.  photo@newsis.com</em></img></span><br/><br/><!--start_block--><div class="highlightBlock" style="margin-top:17px; padding-top:15px; border-top:1px solid #444446; clear:both;"></div><div style="display:none;"><br/></div><div style="display:none;">━<br/></div><b>대구에서 왔다고 격리→착륙 불허까지 <br/></b><div style="display:none;"><br/>━</div><div style="display:none;"><br/></div><div class="highlightBlock" style="margin-bottom:16px; padding-bottom:14px; border-bottom:1px solid #ebebeb; clear:both;"></div><!--end_block-->비엣젯 항공 VJ871편은 지난 2월24일 대구에서 출발, 베트남 다낭시에 도착했다. 베트남 당국은 탑승객 80여명 전원을 곧바로 다낭시내 병원으로 이송·격리했고, 이 중 한국인 20명이 포함돼 있었다. <br/><br/>신종 코로나바이러스 감염증(코로나19) 의심 증상자가 없었는데도 '대구'에서 왔다는 이유였다. 우리 정부는 사전 협의없는 조치였다며 베트남에 엄중 항의했다.<br/><br/>이후 베트남 정부는 대구·경상북도 지역에서 온 입국자와 열이 나는 입국자를 14일간 격리하고, 한국에서 온 입국자는 반드시 검역 설문지를 쓰도록 하는 입국제한 조치를 공식 발표했다.<br/><br/>베트남은 2월29일부터 한국을 포함한 코로나19 확산국가에 대해 15일간 체류할 수 있는 무사증제도를 임시중단했다. 강경화 외교부장관은 팜 빙 베트남 부총리 겸 외교부장관과 통화에서 강한 유감을 표명했지만 효과는 없었다.<br/><br/>베트남의 강경조치는 끝날줄 몰랐다. 2월 29일 한국에서 하노이로 향하던 아시아나항공 여객기가 출발 40분만에 인천공항으로 긴급 회항했다. 베트남 당국이 착륙을 불허했기 때문이다.<br/><br/>주베트남 한국대사가 베트남 보건당국을 접촉, 이를 엄중 항의했다. 외교부는 지난달 3일 서울에서 주한 베트남대사를 초치해 다시 강력항의했다.<br/><br/><!--start_block--><div class="highlightBlock" style="margin-top:17px; padding-top:15px; border-top:1px solid #444446; clear:both;"></div><div style="display:none;"><br/></div><div style="display:none;">━<br/></div><b>엄중항의→삼성·LG 예외인정→중소기업도 필요<br/></b><div style="display:none;"><br/>━</div><div style="display:none;"><br/></div><div class="highlightBlock" style="margin-bottom:16px; padding-bottom:14px; border-bottom:1px solid #ebebeb; clear:both;"></div><!--end_block-->문 대통령이 "건강이 확인된 기업인은 예외로 입국을 허용하자"고 세계 각국에 제안한 것도 베트남 사례의 영향이 컸던 걸로 알려졌다. 삼성의 대규모 투자 등 한-베트남 경제관계가 밀접한데, 기업인들이 교류하지 못하면 양국 경제통상활동이 '셧다운'될 우려가 컸다. <br/><br/>실제로 삼성전자, 삼성디스플레이는 베트남 북부 박닌성에 3조원을 들여 모바일용 디스플레이패널 공장을 세웠다. 이에 정부와 삼성이 적극적으로 베트남을 설득, 한국 엔지니어 파견을 예외로 인정 받았다. <br/><br/>LG그룹도 LG전자, LG디스플레이 등의 엔지니어들을 베트남에 보낼 수 있었다. 삼성, LG 등의 현지공장이 차질을 빚으면 베트남 경제가 타격을 입는다는 사실을 베트남 정부도 인정한 것이다.<br/><br/>문 대통령은 이날 통화에서 "중소기업 인력도 빠른 시일 내 베트남에 입국할 수 있도록 지속적인 관심과 지원을 당부 드린다”고 밝혔다.<br/><br/>한편 문 대통령은 지난달 26일 G20(주요 20개국) 특별 화상정상회의를 한 데 이어, 베트남을 포함한 아세안+3 화상정상회의도 추진중이다. 아세안+3는 아세안10개국에 한중일 3국이 모인 협의체다. <br/><br/>이 회의가 성사되면 기업인, 의료인, 과학자 등 필수인력의 교류 허용을 주제로 다룰 전망이다. G20 화상정상회의 때도 주요 화두였던 사안이다.<br/><br/><!--article_split-->김성휘  기자 sunnykim@mt.co.kr<br/><br/><a href="https://www.mt.co.kr/redirectAd.php?id=0&amp;date=20200305050651" target="_blank">▶줄리아 투자노트</a><br/><a href="https://www.mt.co.kr/redirectAd.php?id=1&amp;date=20200305050651" target="_blank">▶조 변호사의 가정상담소</a> <a href="https://www.mt.co.kr/redirectAd.php?id=2&amp;date=20200305050651" target="_blank">▶머니투데이 구독하기</a> <br/><br/>&lt;저작권자 ⓒ '돈이 보이는 리얼타임 뉴스' 머니투데이, 무단전재 및 재배포 금지&gt;
# 	<!-- // 본문 내용 -->
# </div>

# %%
l = []
for link in df["LinkSrc"]:
    resp = requests.get("http://news.naver.com" + link)
    soup = BeautifulSoup(resp.text, "html.parser")
    content = soup.find(id="articleBodyContents")
    content = content.get_text().replace("\n", "").replace("\t","")
    content = content.replace("// flash 오류를 우회하기 위한 함수 추가function _flash_removeCallback() {}", "")
    l.append(content)

# %%
df['Content'] = l
df.loc[3, 'Content']
# Out:
# '안철수 국민의당 대표가 3일 “정당 선거지원금 440억원 반납하고 투표참가자들에게 마스크 지급하자”고 제안했다.안 대표는 이날 자신의 사회관계망서비스(SNS) 계정에 글을 올려 “코로나19로 모든 국민들이 고통받고 있는데 정당들도 고통 분담에 참여해야 한다”면서 이같이 밝혔다. 안 대표는 “국도를 달리면서 예상외로 많은 분들을 뵀다”면며“다들 꽤 오래전부터 불경기가 시작됐고 코로나19로 주저앉기 일보 직전이라고 울상”이라고 했다. 이어 “그분들의 말씀을 들으면서 생각했다”며 “지금처럼 초유의 어려운 상황에서 과연 정당들이 수백억 원의 국민 세금을 받아 선거를 치르는 것이 타당한가, 우리 정치가 그럴 자격이 있는 것인가에 대해서 말이다”라고 덧붙였다.안 대표는 4·15 총선 선거유세 차원에서 전남 여수부터 출발하는 국토 종주를 하고 있다.안 대표는 “이번 4·15 총선용으로 정당에 지급된 선거보조금은 더불어민주당 120억원, 미래통합당 115억원을 포함해 모두 440억원이나 된다”면서 “기득권 양당의 ‘가짜’ 위성비례정당들이 가져간 돈만도 무려 86억원”이라고 지적했다. 아울러 “그것뿐만이 아닙니다”면서 “가짜 정당들이 모두 정당득표율 3%만 넘기면, 이미 받아간 86억원에 더해서 무려 147억원의 혈세를 추가로 받아간다”고 했다.그는 “정당들은 이미 선거보조금과 별개로 지난해에 432억원, 올해도 110억원을 경상보조금으로 지원받았다”면서 “지금 경제가 총체적 위기에 빠져있고 서민들이 거리에 나 앉을 판에 밥값도 못하면서 국민혈세로 호화판 선거를 치를 때는 아니지 않겠는가”라고 강조했다. 이어 “모든 정당들은 이번 4.15 총선용으로 받은 선거지원금 440억원을 전액 중앙선관위에 반납할 것을 제안한다”면서 “그리고 선관위는 그 반납된 재원을 국고에 귀속시켜 서민생계지원에 사용하도록 하든지, 아니면 마스크를 공적 구입해 투표참가자에게 나누어 줄 것을 제안한다”고 전했다.안 대표는 “공적 마스크 구매가격을 1장에 1000원 정도 계산하면 4400만 장을 구입할 수 있고, 이번 총선 유권자가 4400만 명인데 지난 3개 총선 평균 투표율 52.7%를 감안하면 전 유권자에게 유권자 1인당 2매 정도를 나누어 드릴 수 있다”면서 “저소득층 학생들 온라인 강의를 위한 태블릿 PC를 지원하는 것도 큰 의미가 있다고 생각한다”고 밝혔다. 이어 “가뜩이나 무관심한 선거 분위기 속에서 투표에 대한 관심을 이끌어낼 수 있다고 생각한다”면서 “저의 제안에 대한 각 정당의 호응을 기대한다”고 했다.국민의당 안철수 대표가 지난 1일 오후 전남 여수시 이순신광장에서 국토 400km 종주를 시작하며 달리고 있다./연합뉴스박홍두 기자 phd@kyunghyang.com▶ 장도리 | 그림마당 보기▶ 경향신문 바로가기▶ 경향신문 구독신청하기©경향신문(www.khan.co.kr), 무단전재 및 재배포 금지'

# %% [markdown]
# # Crawling ranking news and refining the text

# %%
# 주요뉴스 헤드라인, 조회수, 내용, 링크 크롤링
def get_news(sectionid, date):
    url = "https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=" + str(sectionid) + "&date=" + str(date)
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, "html.parser")
    ranking_text = soup.find_all(class_ = 'ranking_text')
    
    l = []
    for item in ranking_text:
        d = {}
        d['LinkSrc'] = item.find('a')['href']
        d['Title'] = item.find('a')['title']
        d['Views'] = item.find(class_ = "ranking_view").get_text()
        l.append(d)
    
    for link in l:
        resp = requests.get("http://news.naver.com" + link['LinkSrc'])
        soup = BeautifulSoup(resp.text, "html.parser")
        content = soup.find(id="articleBodyContents")
        link['Content'] = clean_text(content)
        
    df = pd.DataFrame(l)
    return df

# %%
# text 정제하기
def clean_text(text):
    content = text.get_text()
    cleaned_text = re.sub('[a-zA-Z]', '', content)
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>▶@\#$%&\\\=\(\'\"ⓒ(\n)(\t)]', ' ', cleaned_text)
    cleaned_text = cleaned_text.replace("오류를 우회하기 위한 함수 추가 ", "")
    cleaned_text = cleaned_text.replace("동영상 뉴스 오류를 우회하기 위한 함수 추가 ", "")
    cleaned_text = cleaned_text.replace("무단전재 및 재배포 금지", "")
    return cleaned_text

# %%
politics = get_news(100, 20200219)

# %%
politics
# Out:
#                                               LinkSrc  \
# 0   /main/ranking/read.nhn?rankingType=popular_day...
# 1   /main/ranking/read.nhn?rankingType=popular_day...
# 2   /main/ranking/read.nhn?rankingType=popular_day...
# 3   /main/ranking/read.nhn?rankingType=popular_day...
# 4   /main/ranking/read.nhn?rankingType=popular_day...
# 5   /main/ranking/read.nhn?rankingType=popular_day...
# 6   /main/ranking/read.nhn?rankingType=popular_day...
# 7   /main/ranking/read.nhn?rankingType=popular_day...
# 8   /main/ranking/read.nhn?rankingType=popular_day...
# 9   /main/ranking/read.nhn?rankingType=popular_day...
# 10  /main/ranking/read.nhn?rankingType=popular_day...
# 11  /main/ranking/read.nhn?rankingType=popular_day...
# 12  /main/ranking/read.nhn?rankingType=popular_day...
# 13  /main/ranking/read.nhn?rankingType=popular_day...
# 14  /main/ranking/read.nhn?rankingType=popular_day...
# 15  /main/ranking/read.nhn?rankingType=popular_day...
# 16  /main/ranking/read.nhn?rankingType=popular_day...
# 17  /main/ranking/read.nhn?rankingType=popular_day...
# 18  /main/ranking/read.nhn?rankingType=popular_day...
# 19  /main/ranking/read.nhn?rankingType=popular_day...
# 20  /main/ranking/read.nhn?rankingType=popular_day...
# 21  /main/ranking/read.nhn?rankingType=popular_day...
# 22  /main/ranking/read.nhn?rankingType=popular_day...
# 23  /main/ranking/read.nhn?rankingType=popular_day...
# 24  /main/ranking/read.nhn?rankingType=popular_day...
# 25  /main/ranking/read.nhn?rankingType=popular_day...
# 26  /main/ranking/read.nhn?rankingType=popular_day...
# 27  /main/ranking/read.nhn?rankingType=popular_day...
# 28  /main/ranking/read.nhn?rankingType=popular_day...
# 29  /main/ranking/read.nhn?rankingType=popular_day...
#
#                                                 Title    Views  \
# 0                            "진보 진영에 환멸, 떠나려니 울컥해 눈물"  279,086
# 1                   대구 코로나19 확진자, 신천지서 씨클럽까지...난처한 동선  267,570
# 2             '재앙' 16번 말한 심재철 “文 ‘코로나 곧 종식’ 후 환자 쏟아져”  234,488
# 3                  文대통령 "'거지같다' 소탈한 표현… 상인 공격받아 안타까워"  163,976
# 4                무더기 확진 대구 신천지교회… 인근 주민들 "불안해서 외출 자제"  147,526
# 5                      "거지 같아요" 말한 상인 공격…문 대통령 "안타깝다"  147,077
# 6                   대구 코로나19 확진자 다녀간 신천지 폐쇄...'씨클럽'은?  143,182
# 7         김남국 "'조국 수호' 개싸움국민본부 자랑스럽다"…진중권 "개나 소나 與후보"  128,467
# 8                           文 “거지 같아요 언급한 상인 비판 안타까워”  119,641
# 9                 "경기 거지같다" 말한 상인, 文지지자들이 테러…文 "안타깝다"  117,708
# 10                 文 '거지같다' 상인공격 논란 하룻만에 "오해 안타깝다" 왜?  114,925
# 11               [속보] 보건당국 "대구경북 코로나19 추가 확진자 10명 안팎"  113,022
# 12                             '反조국' 찍어내려다 민주당 공천 덧났다  112,075
# 13                  [속보] ‘코로나19’ 日크루즈선 탑승 외국인 국내 입국금지  110,876
# 14                [속보] 미래통합당, 강북 정양석, 인천 남동 유정복 공천 확정   98,601
# 15                    광진을 고민정, 오세훈과 맞붙는다…용인정 이탄희 전략공천   95,805
# 16                          문 대통령 "거지 같다 발언 상인 대변해줘라"   95,485
# 17              유시민 "임미리 칼럼 저질"···진중권 "주제 넘어, 낚시나 가라"   94,152
# 18             문 대통령, ‘거지 같다’ 호소 상인 비난에 “공격받는 것 안타까워”   91,170
# 19                채이배 “당에 남겠다”… 청년정당 통합도 ‘손학규 퇴진’에 달려   88,676
# 20  진중권, '임미리 맹폭' 유시민에 직격탄 "만담을 차지게 해···이젠 기억력마저 잃었나"   88,654
# 21           [속보]이훈 민주당 의원, 총선 불출마 선언 “억울하고 속상하지만···”   86,312
# 22                   고민정 ‘추미애 5선’ 광진을 공천, 오세훈과 맞붙을 전망   85,222
# 23                [단독] 민주당, 조국 '백서저자' 김남국 변호사 카드 '포기'   80,610
# 24                       '거지같다' 발언 상인에 대한 공격…文 "안타깝다"   80,085
# 25                與, '오세훈 광진을'에 고민정 전략공천…용인정엔 이탄희(종합)   79,216
# 26               3선 홍일표, 통합당 첫 컷오프…"윤건영 상대로 김용태 자객공천"   75,957
# 27            靑 "회식, 주52시간제와 무관 홍보"…이재용 부회장 건의 수용(종합)   75,528
# 28            '자객공천'이 조국 사태 소환…"표 떨어지는 소리" 의원들 불만(종합)   74,479
# 29               文대통령 “확진자 크게 늘어…다중시설 방역 더 강화해야” [전문]   74,002
#
#                                               Content
# 0                       미래통합당 합류  청년 정당  브랜드뉴파티  대...
# 1                          이데일리 박지혜 기자  국내 코로나19 신...
# 2                        “대통령은 ‘우한폐렴이 머지않아 종식될 것’이...
# 3                       반찬가게 사장 악의 갖고 한 말 아닌데 비난 받...
# 4                      신천지교회 출입문에는  출입금지  안내문 붙어주변...
# 5       동영상 뉴스                       앵커 문재인 대통령 앞에...
# 6                          이데일리 박지혜 기자  국내 코로나19 신...
# 7                         진중권 전 동양대 교수가 19일 페이스북에 ...
# 8                      악의 없는 소탈한 표현으로 받아들여…극렬 지지층 ...
# 9                        문재인 대통령이 지난 9일 오후 충남 아산시 ...
# 10                     청와대  전날엔 ‘못봐서 모른다’ 한 이유는  “...
# 11                      사진   연합뉴스   디지털뉴스국  기사공유하고...
# 12                     금태섭에 親조국 김남국 도전장… 당내  조국 프레...
# 13                         서울신문 정부  일본 정부에 탑승자 명단 ...
# 14                     미래통합당 김형오 공천관리위원장이 19일 국회 의...
# 15                       고민정 전 대통령비서실 대변인   연합뉴스  ...
# 16      동영상 뉴스                       앵커 지난 9일 문재인 ...
# 17                        사진 페이스북            진중권 전...
# 18                     강민석 청와대 대변인 연합뉴스문재인 대통령이 19...
# 19                         서울신문 바른미래당 채이배 의원이 17일 ...
# 20                     진중권 전 동양대 교수 연합뉴스 서울경제  문재인...
# 21                        이훈 더불어민주당 의원 서울 금천 이 19일...
# 22                     김남국 변호사 출마 포기는 오보 서울신문 고민정 ...
# 23                     출마 기자회견 돌연 취소의원총회 거치면서  안된다...
# 24                     지난 9일 아산 전통시장 방문 당시 한 상인  장...
# 25                     4곳 전략공천 발표…김포갑에 김주영·양산갑 이재영...
# 26                        미래통합당 공천관리위원회 공관위 는 19일 ...
# 27                        청  경제계 건의 전폭 수용 …관세특례 확대...
# 28                     초선 박용진 입장문  당이 잘못  새누리  진박공...
# 29                     문재인 대통령은 19일 신종 코로나바이러스 감염증...

# %% [markdown]
# # Extracting keyword and multiply weight

# %%
# 주요뉴스 헤드라인, 조회수, 내용, 링크 크롤링
def get_news(sectionid, date):
    url = "https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=" + str(sectionid) + "&date=" + str(date)
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, "html.parser")
    ranking_text = soup.find_all(class_ = 'ranking_text')
    
    l = []
    for item in ranking_text:
        d = {}
        d['LinkSrc'] = item.find('a')['href']
        d['Title'] = item.find('a')['title']
        d['Views'] = item.find(class_ = "ranking_view").get_text()
        l.append(d)
    
    for link in l:
        resp = requests.get("http://news.naver.com" + link['LinkSrc'])
        soup = BeautifulSoup(resp.text, "html.parser")
        content = soup.find(id="articleBodyContents")
        link['Content'] = clean_text(content)
        
    df = pd.DataFrame(l)
    return df

# %%
# text 정제하기
def clean_text(text):
    content = text.get_text()
    cleaned_text = re.sub('[a-zA-Z]', '', content)
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>▶@\#$%&\\\=\(\'\"ⓒ(\n)(\t)]', ' ', cleaned_text)
    cleaned_text = cleaned_text.replace("오류를 우회하기 위한 함수 추가 ", "")
    cleaned_text = cleaned_text.replace("동영상 뉴스 오류를 우회하기 위한 함수 추가 ", "")
    cleaned_text = cleaned_text.replace("무단전재 및 재배포 금지", "")
    return cleaned_text

# %%
from konlpy.tag import Komoran
komoran = Komoran()

stop_words = ['에서', '으로', '도록', '기자', '다는', '지만', '라고', '남은', '습니다', '헤럴드', '의원', '대표', '뉴스룸', '뉴스', '서울경제', '뉴시스', '이다']

# %%
import operator
def extract_keyword(df):
    total_dict = {}
    weights = 30
    for content in df['Content']:
        # 각 기사의 키워드 counting순으로 5개 추출
        tokens = komoran.morphs(content)
        tokens = [token for token in tokens if len(token) > 1 and token not in stop_words]
        d = {token : content.count(token) for token in tokens}
        d = dict(sorted(d.items(), key = operator.itemgetter(1), reverse = True)[:5])
        
        # 랭킹별로 각 기사의 키워드에 가중치 곱하고 total_dict에 합치기
        for key in d.keys():
            d[key] = d[key] * weights
            total_dict[key] = total_dict.get(key, 0) + d[key]
            
        weights = weights -1
        
    total_dict = sorted(total_dict.items(), key = operator.itemgetter(1), reverse = True)[:10]
    return total_dict

# %%
print(extract_keyword_(politics))
# Out:
# [('대통령', 1988), ('대구', 1430), ('교회', 1012), ('확진', 863), ('대표', 828), ('지지', 670), ('상인', 664), ('19', 575), ('공천', 563), ('31', 492)]

# %% [markdown]
# # observe the ranking news (politics & society, 0120~0406)

# %%
import time
import datetime
def politic_keywords():
    politic_dataframe = pd.DataFrame()
    date_index = pd.date_range(start = '20200120', end = '20200406')
    date_list = date_index.strftime("%Y%m%d").tolist()
    for i in date_list:
        start = time.time()
        politic_news = get_news(100, i)
        politic_keyword = extract_keyword(politic_news)
        politic_dataframe[i] = politic_keyword
        print(i, time.time()-start)
    return politic_dataframe

# %%
politic_keywords().to_csv('./politics_0406.csv', sep=',', encoding = utf-8-sig)
# Out:
# 20200120 6.9239161014556885
# 20200121 7.206334829330444
# 20200122 6.42830228805542
# 20200123 6.746948957443237
# 20200124 7.131110191345215
# 20200125 6.655661106109619
# 20200126 6.39470100402832
# 20200127 7.94591212272644
# 20200128 6.850723028182983
# 20200129 7.645681619644165
# 20200130 7.815666913986206
# 20200131 8.210883617401123
# 20200201 7.854067325592041
# 20200202 7.898665428161621
# 20200203 7.4025421142578125
# 20200204 7.804372072219849
# 20200205 9.556835889816284
# 20200206 7.59398078918457
# 20200207 8.183098077774048
# 20200208 7.961542129516602
# 20200209 8.526627779006958
# 20200210 7.676929950714111
# 20200211 7.798446893692017
# 20200212 7.813390254974365
# 20200213 8.468688011169434
# 20200214 7.812225341796875
# 20200215 8.050274848937988
# 20200216 8.1515793800354
# 20200217 7.627081394195557
# 20200218 8.037724733352661
# 20200219 7.225550413131714
# 20200220 7.441802263259888
# 20200221 7.405879497528076
# 20200222 8.319660663604736
# 20200223 7.658918142318726
# 20200224 7.245469808578491
# 20200225 7.805427551269531
# 20200226 8.338105201721191
# 20200227 7.739068984985352
# 20200228 7.640505075454712
# 20200229 7.288208246231079
# 20200301 7.7369279861450195
# 20200302 8.409835577011108
# 20200303 7.3920652866363525
# 20200304 8.293156623840332
# 20200305 9.5438814163208
# 20200306 7.4714415073394775
# 20200307 7.728088140487671
# 20200308 7.477708578109741
# 20200309 7.384848594665527
# 20200310 8.026199340820312
# 20200311 7.533135175704956
# 20200312 8.276301860809326
# 20200313 7.231569051742554
# 20200314 7.834198713302612
# 20200315 7.869454622268677
# 20200316 7.6138458251953125
# 20200317 8.299710035324097
# 20200318 7.401876449584961
# 20200319 8.716259479522705
# 20200320 8.010761022567749
# 20200321 7.822447776794434
# 20200322 7.952699661254883
# 20200323 6.991098403930664
# 20200324 7.509814977645874
# 20200325 7.269093990325928
# 20200326 7.527735233306885
# 20200327 7.376036882400513
# 20200328 8.971127033233643
# 20200329 7.457312345504761
# 20200330 7.684667348861694
# 20200331 7.163851737976074
# 20200401 7.37933611869812
# 20200402 7.4591076374053955
# 20200403 7.138444900512695
# 20200404 7.471023321151733
# 20200405 9.11628794670105
# 20200406 7.643417835235596
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5c0bc222fc09> in <module>
# ----> 1 politic_keywords().to_csv('./politics_0406.csv', sep=',', encoding = utf-8-sig)
#
# NameError: name 'utf' is not defined

# %%
politic_0406 = pd.read_csv('./politics_0406.csv')
politic_0406
# Out:
#    Unnamed: 0       20200120        20200121       20200122      20200123  \
# 0           0   ('선물', 1192)     ('관광', 840)   ('전역', 2056)  ('하사', 1835)
# 1           1  ('조계종', 1126)     ('청해', 761)   ('군인', 1381)  ('전역', 1442)
# 2           2    ('육포', 995)     ('한국', 758)   ('하사', 1252)  ('수사', 1096)
# 3           3    ('불교', 845)     ('장관', 704)  ('성전환', 1070)   ('육군', 990)
# 4           4    ('대사', 818)     ('북한', 654)   ('수술', 1047)   ('검찰', 826)
# 5           5    ('한국', 807)     ('미국', 654)    ('복무', 887)   ('태호', 756)
# 6           6   ('안철수', 748)    ('비서관', 653)    ('성전', 609)   ('인사', 635)
# 7           7    ('20', 728)  ('인도네시아', 594)   ('민주당', 501)   ('복무', 620)
# 8           8    ('해리', 600)     ('부대', 591)    ('육군', 479)   ('소청', 613)
# 9           9   ('해리스', 568)    ('대통령', 570)   ('대통령', 406)  ('비서관', 590)
#
#        20200124       20200125       20200126       20200127       20200128  \
# 0  ('검찰', 1471)   ('출마', 1185)  ('김경희', 2637)   ('판사', 1410)  ('민주당', 2982)
# 1  ('하사', 1034)  ('대통령', 1085)  ('위원장', 2450)  ('대통령', 1200)   ('영입', 2914)
# 2   ('수사', 964)    ('진지', 960)  ('김정은', 1929)   ('통합', 1002)   ('인재', 1771)
# 3   ('니다', 951)    ('실장', 737)   ('공연', 1438)   ('김경희', 911)   ('의료', 1375)
# 4   ('전역', 940)    ('검찰', 702)   ('대통령', 945)    ('사법', 907)  ('대통령', 1167)
# 5   ('위원', 887)    ('보수', 681)    ('관람', 870)    ('북한', 869)    ('원종', 725)
# 6  ('대통령', 745)    ('장병', 660)    ('위원', 720)   ('김정은', 786)    ('미투', 700)
# 7   ('지역', 720)    ('총선', 565)    ('지검', 658)   ('위원장', 780)    ('감염', 626)
# 8   ('총리', 567)    ('조사', 540)    ('의료', 542)    ('법원', 740)    ('사실', 481)
# 9   ('권력', 538)    ('정당', 522)    ('국민', 519)   ('백화점', 702)    ('신종', 460)
#
#    ...      20200328       20200329       20200330      20200331  \
# 0  ...  ('후보', 2027)  ('코로나', 1373)   ('지원', 2573)  ('후보', 2779)
# 1  ...   ('선거', 877)    ('후보', 987)   ('후보', 2138)  ('코로나', 960)
# 2  ...   ('개학', 875)    ('시민', 808)   ('가구', 2118)   ('총리', 946)
# 3  ...   ('정당', 775)    ('교회', 776)  ('대통령', 1784)   ('개학', 869)
# 4  ...  ('민주당', 732)    ('교수', 736)   ('경제', 1404)  ('민주당', 845)
# 5  ...   ('교육', 672)    ('가구', 719)   ('소득', 1381)   ('외교', 650)
# 6  ...   ('총리', 664)    ('의료', 707)   ('지급', 1260)  ('아이들', 646)
# 7  ...  ('대통령', 650)    ('북한', 677)   ('정부', 1203)   ('아이', 646)
# 8  ...   ('지급', 626)    ('선거', 656)   ('코로나', 984)   ('통합', 614)
# 9  ...   ('한국', 586)    ('소득', 599)    ('국민', 833)   ('니다', 594)
#
#         20200401      20200402      20200403       20200404       20200405  \
# 0   ('후보', 2615)  ('후보', 1547)  ('선거', 1183)   ('감염', 1954)   ('병원', 1265)
# 1  ('미사일', 1075)   ('서울', 733)   ('후보', 819)  ('베트남', 1648)  ('병원선', 1127)
# 2   ('사일', 1075)   ('광진', 590)   ('한국', 770)   ('후보', 1610)  ('대통령', 1107)
# 3    ('카드', 910)   ('사람', 560)   ('동작', 769)  ('코로나', 1149)    ('배달', 937)
# 4    ('경기', 884)   ('정부', 486)  ('베트남', 750)   ('한국', 1033)    ('19', 783)
# 5   ('코로나', 857)   ('불어', 482)   ('정당', 747)    ('협력', 736)   ('민주당', 748)
# 6    ('통합', 754)  ('호기심', 476)   ('서울', 686)    ('선거', 673)    ('감염', 510)
# 7   ('경기도', 754)   ('처벌', 475)  ('민주당', 549)   ('대통령', 652)    ('우리', 487)
# 8    ('신청', 676)   ('선거', 467)  ('대통령', 544)    ('우리', 627)    ('지사', 464)
# 9    ('사용', 624)  ('민주당', 440)  ('나경원', 508)    ('총리', 550)    ('국민', 462)
#
#         20200406
# 0   ('지원', 2074)
# 1  ('지원금', 2030)
# 2   ('후보', 2023)
# 3   ('재난', 1737)
# 4   ('지급', 1405)
# 5   ('국민', 1365)
# 6    ('긴급', 805)
# 7   ('코로나', 426)
# 8   ('민주당', 421)
# 9    ('통합', 392)
#
# [10 rows x 79 columns]

# %%
import time
import datetime
def society_keyword():
    society_dataframe = pd.DataFrame()
    date_index = pd.date_range(start = '20200201', end = '20200229')
    date_list = date_index.strftime("%Y%m%d").tolist()
    for i in date_list:
        start = time.time()
        society_news = get_news(100, i)
        society_keyword = extract_keyword(society_news)
        society_dataframe[i] = society_keyword
        print(i, time.time()-start)
    return society_dataframe

# %%
society_keyword()
# Out:
# 20200201 9.597592115402222
# 20200202 9.705946207046509
# 20200203 9.503685474395752
# 20200204 9.71315050125122
# 20200205 30.986663818359375
# 20200206 9.386696338653564
# 20200207 9.286553859710693
# 20200208 9.250067234039307
# 20200209 11.163505554199219
# 20200210 9.439119815826416
# 20200211 9.598861694335938
# 20200212 9.873415231704712
# 20200213 9.716944456100464
# 20200214 9.84564757347107
# 20200215 12.249678134918213
# 20200216 10.154577493667603
# 20200217 9.665458917617798
# 20200218 9.320660591125488
# 20200219 9.398812294006348
# 20200220 9.51625680923462
# 20200221 10.0289306640625
# 20200222 9.172717809677124
# 20200223 9.467548131942749
# 20200224 8.734642028808594
# 20200225 8.89930534362793
# 20200226 8.643213510513306
# 20200227 9.05437159538269
# 20200228 10.388607263565063
# 20200229 9.315709829330444
#      20200201    20200202     20200203     20200204     20200205    20200206  \
# 0  (중국, 1762)  (중국, 2479)  (대통령, 1517)   (한국, 1671)  (한국당, 1645)  (출마, 2178)
# 1   (감찰, 783)  (입국, 1658)   (중국, 1033)  (한국당, 1365)   (니다, 1401)  (종로, 1653)
# 2   (지지, 765)  (20, 1160)   (한국당, 838)   (중국, 1108)   (미래, 1354)  (부산, 1246)
# 3   (영입, 760)  (지지, 1044)    (한국, 754)    (미래, 879)  (대통령, 1286)  (니다, 1202)
# 4   (교수, 715)  (코로나, 949)    (지지, 586)   (민주당, 820)   (한국, 1045)   (위원, 999)
# 5   (검찰, 686)   (출마, 888)    (국민, 489)    (검사, 804)   (보건소, 787)   (한국, 723)
# 6   (보수, 645)  (대통령, 767)    (정당, 480)    (대사, 783)    (신종, 674)  (공소장, 650)
# 7  (민주당, 584)  (대변인, 747)    (총리, 473)    (정당, 758)   (공소장, 630)  (대통령, 648)
# 8   (북한, 580)   (북한, 732)    (입국, 446)    (총리, 756)   (성동구, 627)   (공개, 579)
# 9  (대통령, 533)  (20대, 696)   (민주당, 446)    (정부, 607)  (미래한국, 520)   (관위, 567)
#
#      20200207    20200208    20200209     20200210  ...     20200220  \
# 0  (출마, 1811)  (출마, 1911)  (종로, 2349)   (종로, 1667)  ...  (대통령, 4323)
# 1  (종로, 1437)   (공천, 845)  (보수, 2138)  (대통령, 1212)  ...   (감독, 3199)
# 2  (정권, 1200)  (대통령, 798)  (총리, 1887)    (총리, 667)  ...   (영화, 3186)
# 3  (대사, 1013)   (공개, 725)   (교수, 860)    (출마, 623)  ...   (20, 1863)
# 4   (중국, 999)   (중국, 606)  (대통령, 850)    (공사, 473)  ...  (기생충, 1761)
# 5   (관위, 938)  (법무부, 575)   (있다, 832)    (서울, 460)  ...    (배우, 819)
# 6   (총리, 922)  (민주당, 540)   (국민, 784)    (아산, 460)  ...    (제주, 635)
# 7  (한국당, 919)  (공소장, 500)   (선거, 780)   (대변인, 453)  ...   (코로나, 485)
# 8  (대통령, 897)   (있다, 490)   (교민, 722)   (메르스, 408)  ...    (부대, 409)
# 9   (서울, 739)   (서울, 458)   (진천, 717)    (감염, 384)  ...    (지지, 390)
#
#       20200221     20200222     20200223     20200224     20200225  \
# 0  (대통령, 2218)  (코로나, 1549)   (정부, 1990)   (한국, 2308)   (대구, 2646)
# 1  (코로나, 1734)   (확진, 1054)  (대통령, 1660)   (정부, 1664)  (코로나, 2244)
# 2   (공천, 1266)  (대통령, 1004)   (국민, 1150)    (국회, 962)   (지역, 1894)
# 3   (감독, 1063)    (통령, 765)   (코로나, 977)  (이스라엘, 961)   (봉쇄, 1493)
# 4   (영화, 1046)    (지역, 618)    (단계, 755)   (한국인, 909)  (대통령, 1216)
# 5   (19, 1004)    (서울, 590)    (19, 675)    (확진, 869)   (19, 1057)
# 6   (기생충, 988)    (민주, 579)    (감염, 668)   (코로나, 852)    (중국, 995)
# 7    (20, 985)    (공천, 556)    (이러, 621)    (입국, 847)    (한국, 777)
# 8    (서울, 881)    (19, 534)    (지역, 621)    (19, 786)    (입국, 764)
# 9    (지역, 815)   (민주당, 512)   (신천지, 602)   (대통령, 774)   (최대한, 643)
#
#       20200226     20200227     20200228     20200229
# 0  (대통령, 2334)   (청원, 3768)  (대통령, 3244)   (입국, 2754)
# 1   (국민, 1238)  (대통령, 3475)   (청원, 2704)   (중국, 2154)
# 2   (중국, 1153)   (국민, 2190)   (중국, 1934)  (코로나, 1673)
# 3  (코로나, 1093)   (중국, 1930)  (민주당, 1838)  (대통령, 1557)
# 4   (입국, 1086)   (청와대, 968)   (입국, 1636)   (한국, 1307)
# 5    (시장, 977)    (입국, 940)  (코로나, 1296)   (금지, 1290)
# 6    (대구, 977)    (동의, 787)   (정당, 1288)  (신천지, 1068)
# 7   (부시장, 832)   (코로나, 679)   (비례, 1251)    (비례, 593)
# 8    (청원, 780)    (있다, 489)   (탄핵, 1244)   (민주당, 585)
# 9    (부시, 667)    (니다, 460)    (민주, 902)    (공천, 576)
#
# [10 rows x 29 columns]

# %% [markdown]
# # 2) 가중치 range(30,0,-1)에서 views/10000으로 바꿨을 때

# %%
# 주요뉴스 헤드라인, 조회수, 내용, 링크 크롤링
def get_news(sectionid, date):
    url = "https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=" + str(sectionid) + "&date=" + str(date)
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, "html.parser")
    ranking_text = soup.find_all(class_ = 'ranking_text')
    
    l = []
    for item in ranking_text:
        d = {}
        d['LinkSrc'] = item.find('a')['href']
        d['Title'] = item.find('a')['title']
        d['Views'] = item.find(class_ = "ranking_view").get_text()
        d['Views'] = int(re.sub('[,]', '', d['Views']))
        l.append(d)
    
    for link in l:
        resp = requests.get("http://news.naver.com" + link['LinkSrc'])
        soup = BeautifulSoup(resp.text, "html.parser")
        content = soup.find(id="articleBodyContents")
        link['Content'] = clean_text(content)
        
    df = pd.DataFrame(l)
    return df

# %%
# text 정제하기
def clean_text(text):
    content = text.get_text()
    cleaned_text = re.sub('[a-zA-Z]', '', content)
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>▶@\#$%&\\\=\(\'\"ⓒ(\n)(\t)]', ' ', cleaned_text)
    cleaned_text = cleaned_text.replace("오류를 우회하기 위한 함수 추가 ", "")
    cleaned_text = cleaned_text.replace("동영상 뉴스 오류를 우회하기 위한 함수 추가 ", "")
    cleaned_text = cleaned_text.replace("무단전재 및 재배포 금지", "")
    return cleaned_text

# %%
import operator
def extract_keyword_(df):
    total_dict = {}
    index = 0
    for content in df['Content']:
        # 각 기사의 키워드 counting순으로 5개 추출
        tokens = komoran.morphs(content)
        tokens = [token for token in tokens if len(token) > 1 and token not in stop_words]
        d = {token : content.count(token) for token in tokens}
        d = dict(sorted(d.items(), key = operator.itemgetter(1), reverse = True)[:5])
        
        # 랭킹별로 각 기사의 키워드에 가중치 곱하고 total_dict에 합치기
        for key in d.keys():
            d[key] = d[key] * int((df.loc[index, 'Views']/10000))
            total_dict[key] = total_dict.get(key, 0) + d[key]
            
        index = index + 1
        
    total_dict = sorted(total_dict.items(), key = operator.itemgetter(1), reverse = True)[:10]
    return total_dict

# %% [markdown]
# # 3) 조회수 표준편차 구하기

# %%
# 주요뉴스 헤드라인, 조회수, 내용, 링크 크롤링
def get_news_3(sectionid, date):
    url = "https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=" + str(sectionid) + "&date=" + str(date)
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, "html.parser")
    ranking_text = soup.find_all(class_ = 'ranking_text')
    
    l = []
    for item in ranking_text:
        d = {}
        d['LinkSrc'] = item.find('a')['href']
        d['Title'] = item.find('a')['title']
        d['Views'] = item.find(class_ = "ranking_view").get_text()
        d['Views'] = int(re.sub('[,]', '', d['Views']))
        l.append(d)
    
    for link in l:
        resp = requests.get("http://news.naver.com" + link['LinkSrc'])
        soup = BeautifulSoup(resp.text, "html.parser")
        content = soup.find(id="articleBodyContents")
        link['Content'] = clean_text(content)
        
    df = pd.DataFrame(l)
    return df

# %%
politics = get_news_3(100, 20200202)
politics
# Out:
#                                               LinkSrc  \
# 0   /main/ranking/read.nhn?rankingType=popular_day...
# 1   /main/ranking/read.nhn?rankingType=popular_day...
# 2   /main/ranking/read.nhn?rankingType=popular_day...
# 3   /main/ranking/read.nhn?rankingType=popular_day...
# 4   /main/ranking/read.nhn?rankingType=popular_day...
# 5   /main/ranking/read.nhn?rankingType=popular_day...
# 6   /main/ranking/read.nhn?rankingType=popular_day...
# 7   /main/ranking/read.nhn?rankingType=popular_day...
# 8   /main/ranking/read.nhn?rankingType=popular_day...
# 9   /main/ranking/read.nhn?rankingType=popular_day...
# 10  /main/ranking/read.nhn?rankingType=popular_day...
# 11  /main/ranking/read.nhn?rankingType=popular_day...
# 12  /main/ranking/read.nhn?rankingType=popular_day...
# 13  /main/ranking/read.nhn?rankingType=popular_day...
# 14  /main/ranking/read.nhn?rankingType=popular_day...
# 15  /main/ranking/read.nhn?rankingType=popular_day...
# 16  /main/ranking/read.nhn?rankingType=popular_day...
# 17  /main/ranking/read.nhn?rankingType=popular_day...
# 18  /main/ranking/read.nhn?rankingType=popular_day...
# 19  /main/ranking/read.nhn?rankingType=popular_day...
# 20  /main/ranking/read.nhn?rankingType=popular_day...
# 21  /main/ranking/read.nhn?rankingType=popular_day...
# 22  /main/ranking/read.nhn?rankingType=popular_day...
# 23  /main/ranking/read.nhn?rankingType=popular_day...
# 24  /main/ranking/read.nhn?rankingType=popular_day...
# 25  /main/ranking/read.nhn?rankingType=popular_day...
# 26  /main/ranking/read.nhn?rankingType=popular_day...
# 27  /main/ranking/read.nhn?rankingType=popular_day...
# 28  /main/ranking/read.nhn?rankingType=popular_day...
# 29  /main/ranking/read.nhn?rankingType=popular_day...
#
#                                                 Title   Views  \
# 0             미국도 일본도 中 여행객 입국금지 조치내렸는데 한국은 신중한 입장 왜?  382597
# 1          2년반만에 반토막 난 '이여자(20대 여자)' 文지지율… 총선서 어디로 갈까  258453
# 2                      [속보] 한국인·중국인 모두 상대국 관광 목적 입국금지  250379
# 3                    [속보] ‘중국인 입국금지’ 여부, 총리가 직접 발표할 듯  209486
# 4              후베이성 2주내 다녀온 외국인, 한국 못들어온다 [신종 코로나 비상]  206845
# 5                  ‘국경 폐쇄’ 김정은, 시진핑에 신종코로나 지원금과 위문 서한  199044
# 6               [속보] 문 대통령, 전문가 긴급 간담회, 입국금지 조치 논의될 듯  169220
# 7              후베이성 방문 외국인, 4일부터 입국 못한다…첫 입국금지 조치(종합)  168972
# 8                  홍준표 “자의로 탈당해 무소속 출마? 절대 안해…날 제거하면”  168001
# 9                돈줄 마른 김정은, 中에 지원금 보냈다···서한엔 "한집안 식구"  148838
# 10          [속보] “코로나 총력대응”… 문 대통령, 오늘 감염병 전문가 긴급 간담회  138881
# 11                  ‘총선 출마’ 고민정 오늘 민주당 입당…추미애 지역구 나오나  132469
# 12        시즌 1보다 초라한 시즌 2가 될까? 오늘(2일) 4번째 신당 발표하는 안철수  124046
# 13                  [단독]한국당 공관위, 불출마 김무성에 "광주 꽂자" 차출론  117879
# 14                   안철수, 오늘 신당 계획 발표…4년전 '녹색돌풍' 꿈꾸지만  112515
# 15                    "자, 종로는 누가 할래"…한국당, 이낙연 대항마 구인난  107495
# 16                 [속보] 정부 "과도할 정도의 조치할 것…이제부터 중요 고비"  104642
# 17               문 대통령 긴급 간담회...'중국인 방문자 입국 제한' 논의할 듯  102880
# 18                    정세균 “신종코로나 위험지역 중국인 4일부터 입국 제한”  102559
# 19                   정부 “후베이성 2주 내 머문 외국인 4일부터 입국 금지”  101900
# 20             [속보] 고민정 "더 나은 정책·제도로 청춘이 꿈꿀 수 있게 하겠다"  100256
# 21                      고민정 등 언론인 출신 인사 4명, 오늘 민주당 입당   93137
# 22                 민주당 입당 고민정 “출마지 당에 맡겼다”…광진을·동작을 거론   92318
# 23                            정부, 中 후베이성 방문 외국인 입국 금지   91088
# 24  "보수통합? 관심 없고 안가" "중도가 모호? 무식한 궤변"...  '강철수' 카드...   88976
# 25              정 총리 "中 후베이성 2주 내 방문 외국인, 4일부터 입국 금지"   86737
# 26                  고민정·한준호 등 언론인 출신 인사 4명, 오늘 민주당 입당   81286
# 27                    "김의겸·정봉주 어쩌나"…민주당, 리스크 관리 머리 지끈   81070
# 28                      '721번 버스' 또 언급한 고민정, 광진乙 염두했나   77271
# 29             한국당, 제한적 입국금지 비판…"중국 전역이 감염…대책 안이"(종합)   75738
#
#                                               Content
# 0                      세계 각국 잇따라  중국발 입국 금지  조처한국은...
# 1                      문재인 대통령 연합뉴스한국갤럽이 지난 31일 발표...
# 2                          서울신문 입국하는 광저우발 여행객   신종...
# 3                      다른 국가 상황ㆍ입국 금지 실효성 등 종합 고려 ...
# 4                      정부  4일 0시부터 시행한국인은 입국후 2주간 ...
# 5                      “中 전염병 발병에 한 집안 식구  친혈육이 당한...
# 6                      문재인 대통령이 2일 오후 3시에 신종 코로나바이...
# 7                      정세균 총리  오늘 발표… 후베이성 방문 한국 국...
# 8                      ‘고향 출마’ 고수한 洪  공천 탈락시 ‘무소속 ...
# 9                      노동신문  인민일보 시진핑 주석에 위로문 직접 전...
# 10                     문재인 대통령이 31일 오전 청와대 여민관에서 정...
# 11                     김현미·유은혜 불출마 선언한 경기 고양도 거론…수...
# 12                     38명이 시작했는데 남은 건 7명 뿐최대 강점인 ...
# 13                       김무성 자유한국당 의원이 1월 22일 오후 서...
# 14                      실용적 중도 정당  방향성 제시할 듯… 중도  ...
# 15                      험지 출마  황교안 대표 결단 지연…홍준표·김병...
# 16                     사진 연합뉴스정부가 우한 폐렴 신종 코로나 바이러...
# 17      동영상 뉴스                   방역 상황 평가·대책 점검  추...
# 18                      정세균 국무총리가 2일 서울 종로구 정부서울청사...
# 19                     신종 코로나바이러스 감염증 확산이 우려되고 있는 ...
# 20                         고민정 전 청와대 대변인  뉴시스     ...
# 21                     고민정  경기 고양과 서울 동작을  광진을 등 출...
# 22                     언론인 입당식서 윤호중 “가장 편파적 언론 환경”...
# 23                     정세균  신종 코로나 바이러스  대책 발표4일부터...
# 24                     보수통합 참여 묻자  가치 맞다면 이리 오면 돼 ...
# 25                     정부는 모레인 4일 0시부터 중국 후베이성을 2주...
# 26                       고민정 전 청와대 대변인 왼쪽 과 한준호 전 ...
# 27                     김의겸  이해찬 대표에  가혹해  공개편지…3일 ...
# 28                     민주당 입당…수도권 격전지 출마 고민정 전 청와대...
# 29                        황교안 대표 주재 대책 회의…마스크 품귀 현...
